# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# Step 1: Load the image
image_path = '/content/hii.jpg'
image = cv2.imread(image_path)

# Step 2: Check if the image is loaded correctly
if image is None:
    print("Error: The image could not be loaded. Please check the file path.")
else:
    print("Image loaded successfully, shape:", image.shape)  # Debug print

    # Step 3: Convert to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Step 4: Initialize FAST detector
    fast = cv2.FastFeatureDetector_create()

    # Step 5: Detect keypoints
    keypoints = fast.detect(gray_image, None)

    # Step 6: Draw keypoints on the original image
    image_with_keypoints = cv2.drawKeypoints(image, keypoints, None, color=(255, 0, 0))

    # Step 7: Display the result using OpenCV
    cv2_imshow(image_with_keypoints)
# Out:
# Image loaded successfully, shape: (183, 275, 3)
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = '/content/hii.jpg'
image = cv2.imread(image_path)

# Check if the image is loaded correctly
if image is None:
    print("Error: The image could not be loaded. Please check the file path.")
else:
    # Convert to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Initialize FAST detector
    fast = cv2.FastFeatureDetector_create()

    # Detect keypoints
    keypoints = fast.detect(gray_image, None)

    # Draw keypoints on the original image
    image_with_keypoints = cv2.drawKeypoints(image, keypoints, None, color=(255, 0, 0))

    # Display the result using Matplotlib
    plt.figure(figsize=(10, 6))
    plt.imshow(cv2.cvtColor(image_with_keypoints, cv2.COLOR_BGR2RGB))
    plt.title("FAST Keypoints")
    plt.axis('off')
    plt.show()
